# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('filtered_dataAll.csv', sep=';', encoding='utf-8-sig') 
df
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (19,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                     Дата      ДатаДоставки НомерЗаказаНаСайте НовыйСтатус  \
# 0       01.07.2017 00:00  06.07.2017 00:00         5031788_TR   Доставлен
# 1       01.07.2017 00:00  06.07.2017 00:00         5031788_TR   Доставлен
# 2       01.07.2017 00:00  06.07.2017 00:00         5031788_TR   Доставлен
# 3       01.07.2017 00:00  06.07.2017 00:00         5031788_TR   Доставлен
# 4       01.07.2017 00:00  06.07.2017 00:00         5031788_TR   Доставлен
# ...                  ...               ...                ...         ...
# 473499  31.08.2017 23:42  04.09.2017 00:00         5412856_TR   Доставлен
# 473500  31.08.2017 23:42  04.09.2017 00:00         5412856_TR   Доставлен
# 473501  31.08.2017 23:42  04.09.2017 00:00         5412856_TR   Доставлен
# 473502  31.08.2017 23:42  04.09.2017 00:00         5412856_TR   Доставлен
# 473503  31.08.2017 23:42  07.09.2017 00:00         5413024_TR   Доставлен
#
#        СуммаЗаказаНаСайте СуммаДокумента МетодДоставки  ФормаОплаты  \
# 0                   1 634          1 634      Магазины  Безналичная
# 1                   1 634          1 634      Магазины  Безналичная
# 2                   1 634          1 634      Магазины  Безналичная
# 3                   1 634          1 634      Магазины  Безналичная
# 4                   1 634          1 634      Магазины  Безналичная
# ...                   ...            ...           ...          ...
# 473499              3 189          3 189      Магазины  Безналичная
# 473500              3 189          3 189      Магазины  Безналичная
# 473501              3 189          3 189      Магазины  Безналичная
# 473502              3 189          3 189      Магазины  Безналичная
# 473503              1 194          1 194      Магазины  Безналичная
#
#                                   Регион             Группа2  ...  \
# 0                                 Москва  ТЕКСТИЛЬ, ТРИКОТАЖ  ...
# 1                                 Москва  ТЕКСТИЛЬ, ТРИКОТАЖ  ...
# 2                                 Москва  ТЕКСТИЛЬ, ТРИКОТАЖ  ...
# 3                                 Москва  ТЕКСТИЛЬ, ТРИКОТАЖ  ...
# 4                                 Москва  ТЕКСТИЛЬ, ТРИКОТАЖ  ...
# ...                                  ...                 ...  ...
# 473499  Химки (Московская область район)  ТЕКСТИЛЬ, ТРИКОТАЖ  ...
# 473500  Химки (Московская область район)  ТЕКСТИЛЬ, ТРИКОТАЖ  ...
# 473501  Химки (Московская область район)  ТЕКСТИЛЬ, ТРИКОТАЖ  ...
# 473502  Химки (Московская область район)          ПОДГУЗНИКИ  ...
# 473503                         Ярославль          ПОДГУЗНИКИ  ...
#
#                     Телефон_new          ЭлектроннаяПочта_new      Клиент  \
# 0       55574948-52495050484877           116117_tu17@mail.ru     Татьяна
# 1       55574948-52495050484877           116117_tu17@mail.ru     Татьяна
# 2       55574948-52495050484877           116117_tu17@mail.ru     Татьяна
# 3       55574948-52495050484877           116117_tu17@mail.ru     Татьяна
# 4       55574948-52495050484877           116117_tu17@mail.ru     Татьяна
# ...                         ...                           ...         ...
# 473499  55575653-55545554554979  118117_vu22@kamelia-dress.ru   Александр
# 473500  55575653-55545554554979  118117_vu22@kamelia-dress.ru   Александр
# 473501  55575653-55545554554979  118117_vu22@kamelia-dress.ru   Александр
# 473502  55575653-55545554554979  118117_vu22@kamelia-dress.ru   Александр
# 473503  55575048-54534949515576          98109_bm24@gmail.com  Константин
#
#                 ID_SKU     ГородМагазина МагазинЗаказа  НоваяМаржа  \
# 0       IDL00051334048  ИнтернетДоставка           NaN        26,9
# 1       IDL00051367351  ИнтернетДоставка           NaN        26,9
# 2       IDL00007611755  ИнтернетДоставка           NaN        8,04
# 3       IDL00014478250  ИнтернетДоставка           NaN        5,79
# 4       IDL00001209351  ИнтернетДоставка           NaN       63,79
# ...                ...               ...           ...         ...
# 473499  IDL00031153351  ИнтернетДоставка           NaN          39
# 473500  IDL00031222856  ИнтернетДоставка           NaN          39
# 473501  IDL00033741553  ИнтернетДоставка           NaN      202,73
# 473502   ID10005324250  ИнтернетДоставка           NaN      -18,25
# 473503  IDL00028471149  ИнтернетДоставка           NaN         179
#
#         НоваяСуммаСтроки ИспМаржа НовСуммаЗаказаНаСайте
# 0                     50    26.90                  1634
# 1                     50    26.90                  1634
# 2                     49     8.04                  1634
# 3                     40     5.79                  1634
# 4                    169    63.79                  1634
# ...                  ...      ...                   ...
# 473499               239    39.00                  3189
# 473500               259    39.00                  3189
# 473501               670   202.73                  3189
# 473502               755   -18.25                  3189
# 473503              1045   179.00                  1194
#
# [473504 rows x 42 columns]

# %%
def generate_table(df, column_name="МесяцДатыЗаказа"): 
    columns_list = [column_name, 'КоличествоЧеков', 'Средний чек', 'СреднееЧислоТоваровЧека', 'Выручка', 'КоличествоТоваров', 'СредняяМаржа', 'ПроцентОтмен', ] 
    unique_values = df[column_name].unique()
    total = pd.DataFrame(columns=columns_list)
    for val in unique_values: 
        list_of_values = [val] 
        filtered_df = df[df[column_name] == val] 
        # Подсчет значений
        
        df_numb_check = filtered_df['НомерЗаказаНаСайте'].unique()               #кол-во чеков 
        numb_check = df_numb_check.size
        list_of_values.append(numb_check)  
        
        avarage_bill = int(round(filtered_df.groupby(['НомерЗаказаНаСайте']).mean()['НовСуммаЗаказаНаСайте'].mean())) #средний чек 
        list_of_values.append(avarage_bill) 
        
        avarage_numb_good = int(round(filtered_df.groupby(['НомерЗаказаНаСайте']).count()['НовСуммаЗаказаНаСайте'].mean())) #среднее кол-во товаров в  чеке
        list_of_values.append(avarage_numb_good) 
        
        profit = int(round(filtered_df['НоваяСуммаСтроки'].sum()))               #выручка 
        list_of_values.append(profit) 
        
        numb_good = filtered_df['МесяцДатыЗаказа'].size                          #кол-во товаров 
        list_of_values.append(numb_good) 
        
        absmargin = int(round(filtered_df['ИспМаржа'].sum()))                    #средняя маржа 
        list_of_values.append(absmargin/numb_check) 
        
        df_canceled = filtered_df['НомерЗаказаНаСайте'].unique()                 #процент отмен 
        numb_check = df_numb_check.size
        list_of_values.append(numb_check) 

        
        tmp_df = pd.DataFrame([list_of_values], columns=columns_list) 
        total = total.append(tmp_df, ignore_index=True)
    return total

# %%
pivot_table = generate_table(df, column_name="Телефон_new") 
pivot_table
# Out:
#                    Телефон_new КоличествоЧеков Средний чек  \
# 0      55574948-52495050484877               1        1634
# 1      55575155-54535648525672               2       26169
# 2      55575656-49565651494970               1        1915
# 3      55574954-50555651515572               2        1284
# 4      55575348-57505757565774               7        2612
# ...                        ...             ...         ...
# 94533  55574949-50525350495673               1        2189
# 94534  55575649-55555555515377               1        2600
# 94535  55575655-51565156554978               1        1998
# 94536  55575449-49534848495470               1        1540
# 94537  55574955-54485656535172               1        1199
#
#       СреднееЧислоТоваровЧека Выручка КоличествоТоваров  СредняяМаржа  \
# 0                          13    1585                13    497.000000
# 1                           2   26118                 3   3497.500000
# 2                          11    1816                11    -10.000000
# 3                           3    2469                 6    127.500000
# 4                           6   14061                43    375.142857
# ...                       ...     ...               ...           ...
# 94533                       2    2090                 2    358.000000
# 94534                       5    2600                 5   1277.000000
# 94535                       1    1899                 1    267.000000
# 94536                       6    1140                 6    166.000000
# 94537                       1    1199                 1    482.000000
#
#       ПроцентОтмен
# 0                1
# 1                2
# 2                1
# 3                2
# 4                7
# ...            ...
# 94533            1
# 94534            1
# 94535            1
# 94536            1
# 94537            1
#
# [94538 rows x 8 columns]

# %%
pivot_table.to_csv('ВитринаРазмещенные.csv', index=False, sep=';', encoding='utf-8-sig')

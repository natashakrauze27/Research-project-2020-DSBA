# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ### We are going to use pandas and numpy to analyse, filter and create our data. It will be based on excel tables.

# %%
df = pd.read_csv('data.csv', sep=';', encoding='cp1251')

# %%
df
# Out:
#                     Дата     ДатаДоставки НомерЗаказаНаСайте НовыйСтатус  \
# 0        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 1        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 2        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 3        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 4        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# ...                  ...              ...                ...         ...
# 797187  31.08.2017 23:42  06.09.2017 0:00         5413162_TR  К отгрузке
# 797188  31.08.2017 23:42  06.09.2017 0:00         5413162_TR  К отгрузке
# 797189  31.08.2017 23:42  06.09.2017 0:00         5413162_TR  К отгрузке
# 797190  31.08.2017 23:42  06.09.2017 0:00         5413162_TR  К отгрузке
# 797191  31.08.2017 23:42  06.09.2017 0:00         5413162_TR  К отгрузке
#
#        СуммаЗаказаНаСайте СуммаДокумента МетодДоставки  ФормаОплаты  \
# 0                   1 634          1 634      Магазины  Безналичная
# 1                   1 634          1 634      Магазины  Безналичная
# 2                   1 634          1 634      Магазины  Безналичная
# 3                   1 634          1 634      Магазины  Безналичная
# 4                   1 634          1 634      Магазины  Безналичная
# ...                   ...            ...           ...          ...
# 797187              5 611          5 225    Курьерская     Наличная
# 797188              5 611          5 225    Курьерская     Наличная
# 797189              5 611          5 225    Курьерская     Наличная
# 797190              5 611          5 225    Курьерская     Наличная
# 797191              5 611          5 225    Курьерская     Наличная
#
#                                  Регион                   Группа2  ...  \
# 0                                Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...
# 1                                Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...
# 2                                Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...
# 3                                Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...
# 4                                Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...
# ...                                 ...                       ...  ...
# 797187  Путилково (Красногорский район)    КРУПНОГАБАРИТНЫЙ ТОВАР  ...
# 797188  Путилково (Красногорский район)  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...
# 797189  Путилково (Красногорский район)  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...
# 797190  Путилково (Красногорский район)  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...
# 797191  Путилково (Красногорский район)                   ИГРУШКИ  ...
#
#        СуммаДоставки НомерСтроки КоличествоПроданоКлиенту ДатаЗаказаНаСайте  \
# 0                 49           3                        1   30.06.2017 0:00
# 1                 49           4                        1   30.06.2017 0:00
# 2                 49           7                        1   30.06.2017 0:00
# 3                 49           1                        1   30.06.2017 0:00
# 4                 49           9                        1   30.06.2017 0:00
# ...              ...         ...                      ...               ...
# 797187           150           1                        1   31.08.2017 0:00
# 797188           150           8                        1   31.08.2017 0:00
# 797189           150           7                        1   31.08.2017 0:00
# 797190           150           6                        1   31.08.2017 0:00
# 797191           150           5                        1   31.08.2017 0:00
#
#                     Телефон_new ЭлектроннаяПочта_new    Клиент  \
# 0       55574948-52495050484877  116117_tu17@mail.ru   Татьяна
# 1       55574948-52495050484877  116117_tu17@mail.ru   Татьяна
# 2       55574948-52495050484877  116117_tu17@mail.ru   Татьяна
# 3       55574948-52495050484877  116117_tu17@mail.ru   Татьяна
# 4       55574948-52495050484877  116117_tu17@mail.ru   Татьяна
# ...                         ...                  ...       ...
# 797187  55575054-56515648485772  118117_vu18@mail.ru  Виктория
# 797188  55575054-56515648485772  118117_vu18@mail.ru  Виктория
# 797189  55575054-56515648485772  118117_vu18@mail.ru  Виктория
# 797190  55575054-56515648485772  118117_vu18@mail.ru  Виктория
# 797191  55575054-56515648485772  118117_vu18@mail.ru  Виктория
#
#                  ID_SKU ГородМагазина МагазинЗаказа
# 0        IDL00051334048             0           NaN
# 1        IDL00051367351             0           NaN
# 2        IDL00007611755             0           NaN
# 3        IDL00014478250             0           NaN
# 4        IDL00001209351             0           NaN
# ...                 ...           ...           ...
# 797187   IDL00017673957             0           NaN
# 797188  ID000sm-3441856             0           NaN
# 797189   IDL00036203856             0           NaN
# 797190   IDL00033597957             0           NaN
# 797191   IDL00036642351             0           NaN
#
# [797192 rows x 38 columns]

# %%
df.columns
# Out:
# Index(['Дата', 'ДатаДоставки', 'НомерЗаказаНаСайте', 'НовыйСтатус',
#        'СуммаЗаказаНаСайте', 'СуммаДокумента', 'МетодДоставки', 'ФормаОплаты',
#        'Регион', 'Группа2', 'Группа3', 'Группа4', 'Тип', 'Номенклатура',
#        'ТипТовара', 'Отменено', 'ПричинаОтмены', 'Количество', 'Цена',
#        'СуммаСтроки', 'ЦенаЗакупки', 'МесяцДатыЗаказа', 'ГодДатыЗаказа',
#        'ПВЗ_код', 'Статус', 'Гео', 'Маржа', 'СуммаУслуг', 'СуммаДоставки',
#        'НомерСтроки', 'КоличествоПроданоКлиенту', 'ДатаЗаказаНаСайте',
#        'Телефон_new', 'ЭлектроннаяПочта_new', 'Клиент', 'ID_SKU',
#        'ГородМагазина', 'МагазинЗаказа'],
#       dtype='object')

# %% [markdown]
# ### Ориентируемся по 'Новому статусу'. Оставляем только строчки с 'Новым Статусом' == 'Доставлен'.
#
# В 'Статус' = ‘Доставлен’ есть два подварианта: 'НовыйСтатус' = ‘К отгрузке’ и 'НовыйСтатус' = 'Доставлен'.
# Мы выбираем 'Статус' = ‘Доставлен’: 'НовыйСтатус' = 'Доставлен', значит, должны проверить условие только для 'Нового Статуса'.
#
# Если мы будем основываться на доставленных товарах, то избежим пропусков в таких полях как 'Дата Доставки', 'Форма оплаты', 'Город доставки'.

# %%
df = df[df['НовыйСтатус'] == 'Доставлен']

# %%
df
# Out:
#                     Дата     ДатаДоставки НомерЗаказаНаСайте НовыйСтатус  \
# 0        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 1        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 2        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 3        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 4        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# ...                  ...              ...                ...         ...
# 797168  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797169  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797170  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797171  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797172  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
#
#        СуммаЗаказаНаСайте СуммаДокумента МетодДоставки  ФормаОплаты  \
# 0                   1 634          1 634      Магазины  Безналичная
# 1                   1 634          1 634      Магазины  Безналичная
# 2                   1 634          1 634      Магазины  Безналичная
# 3                   1 634          1 634      Магазины  Безналичная
# 4                   1 634          1 634      Магазины  Безналичная
# ...                   ...            ...           ...          ...
# 797168              2 336          2 336      Магазины  Безналичная
# 797169              2 336          2 336      Магазины  Безналичная
# 797170              2 336          2 336      Магазины  Безналичная
# 797171              2 336          2 336      Магазины  Безналичная
# 797172              2 336          2 336      Магазины  Безналичная
#
#                 Регион                   Группа2  ... СуммаДоставки  \
# 0               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 1               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 2               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 3               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 4               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# ...                ...                       ...  ...           ...
# 797168  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
# 797169  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
# 797170  Ростов-на-Дону           ДЕТСКОЕ ПИТАНИЕ  ...            99
# 797171  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
# 797172  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
#
#        НомерСтроки КоличествоПроданоКлиенту ДатаЗаказаНаСайте  \
# 0                3                        1   30.06.2017 0:00
# 1                4                        1   30.06.2017 0:00
# 2                7                        1   30.06.2017 0:00
# 3                1                        1   30.06.2017 0:00
# 4                9                        1   30.06.2017 0:00
# ...            ...                      ...               ...
# 797168           2                        1   31.08.2017 0:00
# 797169           5                        1   31.08.2017 0:00
# 797170           1                        3   31.08.2017 0:00
# 797171           3                        1   31.08.2017 0:00
# 797172           4                        1   31.08.2017 0:00
#
#                     Телефон_new  ЭлектроннаяПочта_new   Клиент  \
# 0       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 1       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 2       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 3       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 4       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# ...                         ...                   ...      ...
# 797168  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797169  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797170  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797171  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797172  55575349-53505051515379  97117_au17@yandex.ru      Аня
#
#                 ID_SKU ГородМагазина МагазинЗаказа
# 0       IDL00051334048             0           NaN
# 1       IDL00051367351             0           NaN
# 2       IDL00007611755             0           NaN
# 3       IDL00014478250             0           NaN
# 4       IDL00001209351             0           NaN
# ...                ...           ...           ...
# 797168  IDL00052147048             0           NaN
# 797169  IDL00006230553             0           NaN
# 797170       ID4516250             0           NaN
# 797171  IDL00029279351             0           NaN
# 797172  IDL00029281957             0           NaN
#
# [359207 rows x 38 columns]

# %% [markdown]
# Было: 797 192 rows
#
# Стало: 359 207 rows

# %% [markdown]
# ### Удалить все строки с количеством доставленного товара == 0.

# %%
df = df[(df['Количество'] > 0)]

# %%
df
# Out:
#                     Дата     ДатаДоставки НомерЗаказаНаСайте НовыйСтатус  \
# 0        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 1        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 2        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 3        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 4        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# ...                  ...              ...                ...         ...
# 797168  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797169  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797170  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797171  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797172  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
#
#        СуммаЗаказаНаСайте СуммаДокумента МетодДоставки  ФормаОплаты  \
# 0                   1 634          1 634      Магазины  Безналичная
# 1                   1 634          1 634      Магазины  Безналичная
# 2                   1 634          1 634      Магазины  Безналичная
# 3                   1 634          1 634      Магазины  Безналичная
# 4                   1 634          1 634      Магазины  Безналичная
# ...                   ...            ...           ...          ...
# 797168              2 336          2 336      Магазины  Безналичная
# 797169              2 336          2 336      Магазины  Безналичная
# 797170              2 336          2 336      Магазины  Безналичная
# 797171              2 336          2 336      Магазины  Безналичная
# 797172              2 336          2 336      Магазины  Безналичная
#
#                 Регион                   Группа2  ... СуммаДоставки  \
# 0               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 1               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 2               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 3               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 4               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# ...                ...                       ...  ...           ...
# 797168  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
# 797169  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
# 797170  Ростов-на-Дону           ДЕТСКОЕ ПИТАНИЕ  ...            99
# 797171  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
# 797172  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
#
#        НомерСтроки КоличествоПроданоКлиенту ДатаЗаказаНаСайте  \
# 0                3                        1   30.06.2017 0:00
# 1                4                        1   30.06.2017 0:00
# 2                7                        1   30.06.2017 0:00
# 3                1                        1   30.06.2017 0:00
# 4                9                        1   30.06.2017 0:00
# ...            ...                      ...               ...
# 797168           2                        1   31.08.2017 0:00
# 797169           5                        1   31.08.2017 0:00
# 797170           1                        3   31.08.2017 0:00
# 797171           3                        1   31.08.2017 0:00
# 797172           4                        1   31.08.2017 0:00
#
#                     Телефон_new  ЭлектроннаяПочта_new   Клиент  \
# 0       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 1       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 2       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 3       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 4       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# ...                         ...                   ...      ...
# 797168  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797169  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797170  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797171  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797172  55575349-53505051515379  97117_au17@yandex.ru      Аня
#
#                 ID_SKU ГородМагазина МагазинЗаказа
# 0       IDL00051334048             0           NaN
# 1       IDL00051367351             0           NaN
# 2       IDL00007611755             0           NaN
# 3       IDL00014478250             0           NaN
# 4       IDL00001209351             0           NaN
# ...                ...           ...           ...
# 797168  IDL00052147048             0           NaN
# 797169  IDL00006230553             0           NaN
# 797170       ID4516250             0           NaN
# 797171  IDL00029279351             0           NaN
# 797172  IDL00029281957             0           NaN
#
# [356893 rows x 38 columns]

# %% [markdown]
# Было: 359 207 rows
#
# Стало: 356 893 rows

# %% [markdown]
# ### Удалить строки в колонке ‘Отменено’, где стоит 'да' - нам не интересные покупатели, которые отменили заказ для составления витрины.

# %%
df = df[(df['Отменено'] != 'Да')]

# %%
df
# Out:
#                     Дата     ДатаДоставки НомерЗаказаНаСайте НовыйСтатус  \
# 0        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 1        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 2        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 3        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 4        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# ...                  ...              ...                ...         ...
# 797168  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797169  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797170  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797171  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797172  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
#
#        СуммаЗаказаНаСайте СуммаДокумента МетодДоставки  ФормаОплаты  \
# 0                   1 634          1 634      Магазины  Безналичная
# 1                   1 634          1 634      Магазины  Безналичная
# 2                   1 634          1 634      Магазины  Безналичная
# 3                   1 634          1 634      Магазины  Безналичная
# 4                   1 634          1 634      Магазины  Безналичная
# ...                   ...            ...           ...          ...
# 797168              2 336          2 336      Магазины  Безналичная
# 797169              2 336          2 336      Магазины  Безналичная
# 797170              2 336          2 336      Магазины  Безналичная
# 797171              2 336          2 336      Магазины  Безналичная
# 797172              2 336          2 336      Магазины  Безналичная
#
#                 Регион                   Группа2  ... СуммаДоставки  \
# 0               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 1               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 2               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 3               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 4               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# ...                ...                       ...  ...           ...
# 797168  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
# 797169  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
# 797170  Ростов-на-Дону           ДЕТСКОЕ ПИТАНИЕ  ...            99
# 797171  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
# 797172  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
#
#        НомерСтроки КоличествоПроданоКлиенту ДатаЗаказаНаСайте  \
# 0                3                        1   30.06.2017 0:00
# 1                4                        1   30.06.2017 0:00
# 2                7                        1   30.06.2017 0:00
# 3                1                        1   30.06.2017 0:00
# 4                9                        1   30.06.2017 0:00
# ...            ...                      ...               ...
# 797168           2                        1   31.08.2017 0:00
# 797169           5                        1   31.08.2017 0:00
# 797170           1                        3   31.08.2017 0:00
# 797171           3                        1   31.08.2017 0:00
# 797172           4                        1   31.08.2017 0:00
#
#                     Телефон_new  ЭлектроннаяПочта_new   Клиент  \
# 0       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 1       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 2       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 3       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 4       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# ...                         ...                   ...      ...
# 797168  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797169  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797170  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797171  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797172  55575349-53505051515379  97117_au17@yandex.ru      Аня
#
#                 ID_SKU ГородМагазина МагазинЗаказа
# 0       IDL00051334048             0           NaN
# 1       IDL00051367351             0           NaN
# 2       IDL00007611755             0           NaN
# 3       IDL00014478250             0           NaN
# 4       IDL00001209351             0           NaN
# ...                ...           ...           ...
# 797168  IDL00052147048             0           NaN
# 797169  IDL00006230553             0           NaN
# 797170       ID4516250             0           NaN
# 797171  IDL00029279351             0           NaN
# 797172  IDL00029281957             0           NaN
#
# [352541 rows x 38 columns]

# %% [markdown]
# Было: 356 893 rows
#
# Стало: 352 541 rows

# %% [markdown]
# ### Удалить строки если сумма заказа = 0 или сумма документа = 0, тк как нам не интересно это для составления витрины.

# %%
df = df[(df['СуммаЗаказаНаСайте'] != 0) | (df['СуммаДокумента'] != 0)]

# %%
df
# Out:
#                     Дата     ДатаДоставки НомерЗаказаНаСайте НовыйСтатус  \
# 0        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 1        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 2        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 3        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 4        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# ...                  ...              ...                ...         ...
# 797168  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797169  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797170  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797171  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797172  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
#
#        СуммаЗаказаНаСайте СуммаДокумента МетодДоставки  ФормаОплаты  \
# 0                   1 634          1 634      Магазины  Безналичная
# 1                   1 634          1 634      Магазины  Безналичная
# 2                   1 634          1 634      Магазины  Безналичная
# 3                   1 634          1 634      Магазины  Безналичная
# 4                   1 634          1 634      Магазины  Безналичная
# ...                   ...            ...           ...          ...
# 797168              2 336          2 336      Магазины  Безналичная
# 797169              2 336          2 336      Магазины  Безналичная
# 797170              2 336          2 336      Магазины  Безналичная
# 797171              2 336          2 336      Магазины  Безналичная
# 797172              2 336          2 336      Магазины  Безналичная
#
#                 Регион                   Группа2  ... СуммаДоставки  \
# 0               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 1               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 2               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 3               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 4               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# ...                ...                       ...  ...           ...
# 797168  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
# 797169  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
# 797170  Ростов-на-Дону           ДЕТСКОЕ ПИТАНИЕ  ...            99
# 797171  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
# 797172  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
#
#        НомерСтроки КоличествоПроданоКлиенту ДатаЗаказаНаСайте  \
# 0                3                        1   30.06.2017 0:00
# 1                4                        1   30.06.2017 0:00
# 2                7                        1   30.06.2017 0:00
# 3                1                        1   30.06.2017 0:00
# 4                9                        1   30.06.2017 0:00
# ...            ...                      ...               ...
# 797168           2                        1   31.08.2017 0:00
# 797169           5                        1   31.08.2017 0:00
# 797170           1                        3   31.08.2017 0:00
# 797171           3                        1   31.08.2017 0:00
# 797172           4                        1   31.08.2017 0:00
#
#                     Телефон_new  ЭлектроннаяПочта_new   Клиент  \
# 0       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 1       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 2       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 3       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 4       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# ...                         ...                   ...      ...
# 797168  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797169  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797170  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797171  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797172  55575349-53505051515379  97117_au17@yandex.ru      Аня
#
#                 ID_SKU ГородМагазина МагазинЗаказа
# 0       IDL00051334048             0           NaN
# 1       IDL00051367351             0           NaN
# 2       IDL00007611755             0           NaN
# 3       IDL00014478250             0           NaN
# 4       IDL00001209351             0           NaN
# ...                ...           ...           ...
# 797168  IDL00052147048             0           NaN
# 797169  IDL00006230553             0           NaN
# 797170       ID4516250             0           NaN
# 797171  IDL00029279351             0           NaN
# 797172  IDL00029281957             0           NaN
#
# [352541 rows x 38 columns]

# %% [markdown]
# Было: 352 541 rows
#
# Стало: 352 541 rows
#
# Цифра не изменилась, значит, ошибок по этому пункту в таблице не было.

# %% [markdown]
# ### Удалить все строки с количеством продано клиенту == 0.

# %%
df = df[(df['КоличествоПроданоКлиенту'] > 0)]

# %%
df
# Out:
#                     Дата     ДатаДоставки НомерЗаказаНаСайте НовыйСтатус  \
# 0        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 1        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 2        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 3        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 4        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# ...                  ...              ...                ...         ...
# 797168  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797169  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797170  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797171  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797172  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
#
#        СуммаЗаказаНаСайте СуммаДокумента МетодДоставки  ФормаОплаты  \
# 0                   1 634          1 634      Магазины  Безналичная
# 1                   1 634          1 634      Магазины  Безналичная
# 2                   1 634          1 634      Магазины  Безналичная
# 3                   1 634          1 634      Магазины  Безналичная
# 4                   1 634          1 634      Магазины  Безналичная
# ...                   ...            ...           ...          ...
# 797168              2 336          2 336      Магазины  Безналичная
# 797169              2 336          2 336      Магазины  Безналичная
# 797170              2 336          2 336      Магазины  Безналичная
# 797171              2 336          2 336      Магазины  Безналичная
# 797172              2 336          2 336      Магазины  Безналичная
#
#                 Регион                   Группа2  ... СуммаДоставки  \
# 0               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 1               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 2               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 3               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 4               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# ...                ...                       ...  ...           ...
# 797168  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
# 797169  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
# 797170  Ростов-на-Дону           ДЕТСКОЕ ПИТАНИЕ  ...            99
# 797171  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
# 797172  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
#
#        НомерСтроки КоличествоПроданоКлиенту ДатаЗаказаНаСайте  \
# 0                3                        1   30.06.2017 0:00
# 1                4                        1   30.06.2017 0:00
# 2                7                        1   30.06.2017 0:00
# 3                1                        1   30.06.2017 0:00
# 4                9                        1   30.06.2017 0:00
# ...            ...                      ...               ...
# 797168           2                        1   31.08.2017 0:00
# 797169           5                        1   31.08.2017 0:00
# 797170           1                        3   31.08.2017 0:00
# 797171           3                        1   31.08.2017 0:00
# 797172           4                        1   31.08.2017 0:00
#
#                     Телефон_new  ЭлектроннаяПочта_new   Клиент  \
# 0       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 1       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 2       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 3       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 4       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# ...                         ...                   ...      ...
# 797168  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797169  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797170  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797171  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797172  55575349-53505051515379  97117_au17@yandex.ru      Аня
#
#                 ID_SKU ГородМагазина МагазинЗаказа
# 0       IDL00051334048             0           NaN
# 1       IDL00051367351             0           NaN
# 2       IDL00007611755             0           NaN
# 3       IDL00014478250             0           NaN
# 4       IDL00001209351             0           NaN
# ...                ...           ...           ...
# 797168  IDL00052147048             0           NaN
# 797169  IDL00006230553             0           NaN
# 797170       ID4516250             0           NaN
# 797171  IDL00029279351             0           NaN
# 797172  IDL00029281957             0           NaN
#
# [349567 rows x 38 columns]

# %% [markdown]
# Было: 352 541 rows
#
# Стало: 349 567 rows

# %% [markdown]
# ### Мы решили заменить в столбце 'ГородМагазина', где значение строк равно 0 на показатель "ИнтернетДоставка".

# %%
df.loc[df['ГородМагазина'] == '0', 'ГородМагазина'] = 'ИнтернетДоставка'

# %%
df
# Out:
#                     Дата     ДатаДоставки НомерЗаказаНаСайте НовыйСтатус  \
# 0        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 1        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 2        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 3        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 4        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# ...                  ...              ...                ...         ...
# 797168  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797169  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797170  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797171  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797172  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
#
#        СуммаЗаказаНаСайте СуммаДокумента МетодДоставки  ФормаОплаты  \
# 0                   1 634          1 634      Магазины  Безналичная
# 1                   1 634          1 634      Магазины  Безналичная
# 2                   1 634          1 634      Магазины  Безналичная
# 3                   1 634          1 634      Магазины  Безналичная
# 4                   1 634          1 634      Магазины  Безналичная
# ...                   ...            ...           ...          ...
# 797168              2 336          2 336      Магазины  Безналичная
# 797169              2 336          2 336      Магазины  Безналичная
# 797170              2 336          2 336      Магазины  Безналичная
# 797171              2 336          2 336      Магазины  Безналичная
# 797172              2 336          2 336      Магазины  Безналичная
#
#                 Регион                   Группа2  ... СуммаДоставки  \
# 0               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 1               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 2               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 3               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 4               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# ...                ...                       ...  ...           ...
# 797168  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
# 797169  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
# 797170  Ростов-на-Дону           ДЕТСКОЕ ПИТАНИЕ  ...            99
# 797171  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
# 797172  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
#
#        НомерСтроки КоличествоПроданоКлиенту ДатаЗаказаНаСайте  \
# 0                3                        1   30.06.2017 0:00
# 1                4                        1   30.06.2017 0:00
# 2                7                        1   30.06.2017 0:00
# 3                1                        1   30.06.2017 0:00
# 4                9                        1   30.06.2017 0:00
# ...            ...                      ...               ...
# 797168           2                        1   31.08.2017 0:00
# 797169           5                        1   31.08.2017 0:00
# 797170           1                        3   31.08.2017 0:00
# 797171           3                        1   31.08.2017 0:00
# 797172           4                        1   31.08.2017 0:00
#
#                     Телефон_new  ЭлектроннаяПочта_new   Клиент  \
# 0       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 1       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 2       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 3       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 4       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# ...                         ...                   ...      ...
# 797168  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797169  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797170  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797171  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797172  55575349-53505051515379  97117_au17@yandex.ru      Аня
#
#                 ID_SKU     ГородМагазина МагазинЗаказа
# 0       IDL00051334048  ИнтернетДоставка           NaN
# 1       IDL00051367351  ИнтернетДоставка           NaN
# 2       IDL00007611755  ИнтернетДоставка           NaN
# 3       IDL00014478250  ИнтернетДоставка           NaN
# 4       IDL00001209351  ИнтернетДоставка           NaN
# ...                ...               ...           ...
# 797168  IDL00052147048  ИнтернетДоставка           NaN
# 797169  IDL00006230553  ИнтернетДоставка           NaN
# 797170       ID4516250  ИнтернетДоставка           NaN
# 797171  IDL00029279351  ИнтернетДоставка           NaN
# 797172  IDL00029281957  ИнтернетДоставка           NaN
#
# [349567 rows x 38 columns]

# %% [markdown]
# ### Мы решили удалить все строки, где написано "Доставка" в столбце "Номенклатура", и соотвественно, в столбцах "Группа2", потому что Доставка не может считаться полноценным заказом.

# %%
df = df[df['Номенклатура'] != 'Доставка']

# %%
df
# Out:
#                     Дата     ДатаДоставки НомерЗаказаНаСайте НовыйСтатус  \
# 0        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 1        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 2        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 3        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# 4        01.07.2017 0:00  06.07.2017 0:00         5031788_TR   Доставлен
# ...                  ...              ...                ...         ...
# 797168  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797169  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797170  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797171  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
# 797172  31.08.2017 23:42  14.09.2017 0:00         5413126_TR   Доставлен
#
#        СуммаЗаказаНаСайте СуммаДокумента МетодДоставки  ФормаОплаты  \
# 0                   1 634          1 634      Магазины  Безналичная
# 1                   1 634          1 634      Магазины  Безналичная
# 2                   1 634          1 634      Магазины  Безналичная
# 3                   1 634          1 634      Магазины  Безналичная
# 4                   1 634          1 634      Магазины  Безналичная
# ...                   ...            ...           ...          ...
# 797168              2 336          2 336      Магазины  Безналичная
# 797169              2 336          2 336      Магазины  Безналичная
# 797170              2 336          2 336      Магазины  Безналичная
# 797171              2 336          2 336      Магазины  Безналичная
# 797172              2 336          2 336      Магазины  Безналичная
#
#                 Регион                   Группа2  ... СуммаДоставки  \
# 0               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 1               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 2               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 3               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# 4               Москва        ТЕКСТИЛЬ, ТРИКОТАЖ  ...            49
# ...                ...                       ...  ...           ...
# 797168  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
# 797169  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
# 797170  Ростов-на-Дону           ДЕТСКОЕ ПИТАНИЕ  ...            99
# 797171  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
# 797172  Ростов-на-Дону  КАНЦТОВАРЫ, КНИГИ, ДИСКИ  ...            99
#
#        НомерСтроки КоличествоПроданоКлиенту ДатаЗаказаНаСайте  \
# 0                3                        1   30.06.2017 0:00
# 1                4                        1   30.06.2017 0:00
# 2                7                        1   30.06.2017 0:00
# 3                1                        1   30.06.2017 0:00
# 4                9                        1   30.06.2017 0:00
# ...            ...                      ...               ...
# 797168           2                        1   31.08.2017 0:00
# 797169           5                        1   31.08.2017 0:00
# 797170           1                        3   31.08.2017 0:00
# 797171           3                        1   31.08.2017 0:00
# 797172           4                        1   31.08.2017 0:00
#
#                     Телефон_new  ЭлектроннаяПочта_new   Клиент  \
# 0       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 1       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 2       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 3       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# 4       55574948-52495050484877   116117_tu17@mail.ru  Татьяна
# ...                         ...                   ...      ...
# 797168  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797169  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797170  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797171  55575349-53505051515379  97117_au17@yandex.ru      Аня
# 797172  55575349-53505051515379  97117_au17@yandex.ru      Аня
#
#                 ID_SKU     ГородМагазина МагазинЗаказа
# 0       IDL00051334048  ИнтернетДоставка           NaN
# 1       IDL00051367351  ИнтернетДоставка           NaN
# 2       IDL00007611755  ИнтернетДоставка           NaN
# 3       IDL00014478250  ИнтернетДоставка           NaN
# 4       IDL00001209351  ИнтернетДоставка           NaN
# ...                ...               ...           ...
# 797168  IDL00052147048  ИнтернетДоставка           NaN
# 797169  IDL00006230553  ИнтернетДоставка           NaN
# 797170       ID4516250  ИнтернетДоставка           NaN
# 797171  IDL00029279351  ИнтернетДоставка           NaN
# 797172  IDL00029281957  ИнтернетДоставка           NaN
#
# [267691 rows x 38 columns]

# %% [markdown]
# Было: 349 567 rows
#
# Стало: 267 691 rows

# %%
df.to_csv('filtered_dataBuyed.csv', index=False, sep=';', encoding='utf-8-sig')

# %% [markdown]
# ### Мы создаем новую таблицу. В экселе редактируем и убираем пустные значения в столбце "Регион", заменяя их на значения из столбца "Город магазина".

# %%
df = pd.read_csv('filtered_dataBuyed2.csv', sep=';', encoding='utf-8-sig')

# %%
df
# Out:
#                     Дата      ДатаДоставки НомерЗаказаНаСайте НовыйСтатус  \
# 0       01.07.2017 00:00  06.07.2017 00:00         5031788_TR   Доставлен
# 1       01.07.2017 00:00  06.07.2017 00:00         5031788_TR   Доставлен
# 2       01.07.2017 00:00  06.07.2017 00:00         5031788_TR   Доставлен
# 3       01.07.2017 00:00  06.07.2017 00:00         5031788_TR   Доставлен
# 4       01.07.2017 00:00  06.07.2017 00:00         5031788_TR   Доставлен
# ...                  ...               ...                ...         ...
# 267686  31.08.2017 23:42  04.09.2017 00:00         5412856_TR   Доставлен
# 267687  31.08.2017 23:42  04.09.2017 00:00         5412856_TR   Доставлен
# 267688  31.08.2017 23:42  04.09.2017 00:00         5412856_TR   Доставлен
# 267689  31.08.2017 23:42  04.09.2017 00:00         5412856_TR   Доставлен
# 267690  31.08.2017 23:42  07.09.2017 00:00         5413024_TR   Доставлен
#
#        СуммаЗаказаНаСайте СуммаДокумента МетодДоставки  ФормаОплаты  \
# 0                   1 634          1 634      Магазины  Безналичная
# 1                   1 634          1 634      Магазины  Безналичная
# 2                   1 634          1 634      Магазины  Безналичная
# 3                   1 634          1 634      Магазины  Безналичная
# 4                   1 634          1 634      Магазины  Безналичная
# ...                   ...            ...           ...          ...
# 267686              3 189          3 189      Магазины  Безналичная
# 267687              3 189          3 189      Магазины  Безналичная
# 267688              3 189          3 189      Магазины  Безналичная
# 267689              3 189          3 189      Магазины  Безналичная
# 267690              1 194          1 194      Магазины  Безналичная
#
#                                   Регион             Группа2  ... НомерСтроки  \
# 0                                 Москва  ТЕКСТИЛЬ, ТРИКОТАЖ  ...           3
# 1                                 Москва  ТЕКСТИЛЬ, ТРИКОТАЖ  ...           4
# 2                                 Москва  ТЕКСТИЛЬ, ТРИКОТАЖ  ...           7
# 3                                 Москва  ТЕКСТИЛЬ, ТРИКОТАЖ  ...           1
# 4                                 Москва  ТЕКСТИЛЬ, ТРИКОТАЖ  ...           9
# ...                                  ...                 ...  ...         ...
# 267686  Химки (Московская область район)  ТЕКСТИЛЬ, ТРИКОТАЖ  ...           9
# 267687  Химки (Московская область район)  ТЕКСТИЛЬ, ТРИКОТАЖ  ...           7
# 267688  Химки (Московская область район)  ТЕКСТИЛЬ, ТРИКОТАЖ  ...           3
# 267689  Химки (Московская область район)          ПОДГУЗНИКИ  ...           8
# 267690                         Ярославль          ПОДГУЗНИКИ  ...           1
#
#        КоличествоПроданоКлиенту ДатаЗаказаНаСайте              Телефон_new  \
# 0                             1  30.06.2017 00:00  55574948-52495050484877
# 1                             1  30.06.2017 00:00  55574948-52495050484877
# 2                             1  30.06.2017 00:00  55574948-52495050484877
# 3                             1  30.06.2017 00:00  55574948-52495050484877
# 4                             1  30.06.2017 00:00  55574948-52495050484877
# ...                         ...               ...                      ...
# 267686                        1  31.08.2017 00:00  55575653-55545554554979
# 267687                        1  31.08.2017 00:00  55575653-55545554554979
# 267688                        1  31.08.2017 00:00  55575653-55545554554979
# 267689                        1  31.08.2017 00:00  55575653-55545554554979
# 267690                        1  31.08.2017 00:00  55575048-54534949515576
#
#                 ЭлектроннаяПочта_new      Клиент          ID_SKU  \
# 0                116117_tu17@mail.ru     Татьяна  IDL00051334048
# 1                116117_tu17@mail.ru     Татьяна  IDL00051367351
# 2                116117_tu17@mail.ru     Татьяна  IDL00007611755
# 3                116117_tu17@mail.ru     Татьяна  IDL00014478250
# 4                116117_tu17@mail.ru     Татьяна  IDL00001209351
# ...                              ...         ...             ...
# 267686  118117_vu22@kamelia-dress.ru   Александр  IDL00031153351
# 267687  118117_vu22@kamelia-dress.ru   Александр  IDL00031222856
# 267688  118117_vu22@kamelia-dress.ru   Александр  IDL00033741553
# 267689  118117_vu22@kamelia-dress.ru   Александр   ID10005324250
# 267690          98109_bm24@gmail.com  Константин  IDL00028471149
#
#            ГородМагазина МагазинЗаказа НоваяМаржа
# 0       ИнтернетДоставка           NaN        26,9
# 1       ИнтернетДоставка           NaN        8,04
# 2       ИнтернетДоставка           NaN        5,79
# 3       ИнтернетДоставка           NaN       63,79
# 4       ИнтернетДоставка           NaN       95,18
# ...                  ...           ...         ...
# 267686  ИнтернетДоставка           NaN          39
# 267687  ИнтернетДоставка           NaN      202,73
# 267688  ИнтернетДоставка           NaN      -18,25
# 267689  ИнтернетДоставка           NaN         179
# 267690  ИнтернетДоставка           NaN           0
#
# [267691 rows x 39 columns]

# %% [markdown]
# ### Теперь мы должны проверить остались ли заказы в кторых в столбце "Регион" стоят пустые значения - такие строки нам нужно удалить.

# %%
df = df[(df['Регион'] != None)]

# %%
df
# Out:
#                     Дата      ДатаДоставки НомерЗаказаНаСайте НовыйСтатус  \
# 0       01.07.2017 00:00  06.07.2017 00:00         5031788_TR   Доставлен
# 1       01.07.2017 00:00  06.07.2017 00:00         5031788_TR   Доставлен
# 2       01.07.2017 00:00  06.07.2017 00:00         5031788_TR   Доставлен
# 3       01.07.2017 00:00  06.07.2017 00:00         5031788_TR   Доставлен
# 4       01.07.2017 00:00  06.07.2017 00:00         5031788_TR   Доставлен
# ...                  ...               ...                ...         ...
# 267686  31.08.2017 23:42  04.09.2017 00:00         5412856_TR   Доставлен
# 267687  31.08.2017 23:42  04.09.2017 00:00         5412856_TR   Доставлен
# 267688  31.08.2017 23:42  04.09.2017 00:00         5412856_TR   Доставлен
# 267689  31.08.2017 23:42  04.09.2017 00:00         5412856_TR   Доставлен
# 267690  31.08.2017 23:42  07.09.2017 00:00         5413024_TR   Доставлен
#
#        СуммаЗаказаНаСайте СуммаДокумента МетодДоставки  ФормаОплаты  \
# 0                   1 634          1 634      Магазины  Безналичная
# 1                   1 634          1 634      Магазины  Безналичная
# 2                   1 634          1 634      Магазины  Безналичная
# 3                   1 634          1 634      Магазины  Безналичная
# 4                   1 634          1 634      Магазины  Безналичная
# ...                   ...            ...           ...          ...
# 267686              3 189          3 189      Магазины  Безналичная
# 267687              3 189          3 189      Магазины  Безналичная
# 267688              3 189          3 189      Магазины  Безналичная
# 267689              3 189          3 189      Магазины  Безналичная
# 267690              1 194          1 194      Магазины  Безналичная
#
#                                   Регион             Группа2  ... НомерСтроки  \
# 0                                 Москва  ТЕКСТИЛЬ, ТРИКОТАЖ  ...           3
# 1                                 Москва  ТЕКСТИЛЬ, ТРИКОТАЖ  ...           4
# 2                                 Москва  ТЕКСТИЛЬ, ТРИКОТАЖ  ...           7
# 3                                 Москва  ТЕКСТИЛЬ, ТРИКОТАЖ  ...           1
# 4                                 Москва  ТЕКСТИЛЬ, ТРИКОТАЖ  ...           9
# ...                                  ...                 ...  ...         ...
# 267686  Химки (Московская область район)  ТЕКСТИЛЬ, ТРИКОТАЖ  ...           9
# 267687  Химки (Московская область район)  ТЕКСТИЛЬ, ТРИКОТАЖ  ...           7
# 267688  Химки (Московская область район)  ТЕКСТИЛЬ, ТРИКОТАЖ  ...           3
# 267689  Химки (Московская область район)          ПОДГУЗНИКИ  ...           8
# 267690                         Ярославль          ПОДГУЗНИКИ  ...           1
#
#        КоличествоПроданоКлиенту ДатаЗаказаНаСайте              Телефон_new  \
# 0                             1  30.06.2017 00:00  55574948-52495050484877
# 1                             1  30.06.2017 00:00  55574948-52495050484877
# 2                             1  30.06.2017 00:00  55574948-52495050484877
# 3                             1  30.06.2017 00:00  55574948-52495050484877
# 4                             1  30.06.2017 00:00  55574948-52495050484877
# ...                         ...               ...                      ...
# 267686                        1  31.08.2017 00:00  55575653-55545554554979
# 267687                        1  31.08.2017 00:00  55575653-55545554554979
# 267688                        1  31.08.2017 00:00  55575653-55545554554979
# 267689                        1  31.08.2017 00:00  55575653-55545554554979
# 267690                        1  31.08.2017 00:00  55575048-54534949515576
#
#                 ЭлектроннаяПочта_new      Клиент          ID_SKU  \
# 0                116117_tu17@mail.ru     Татьяна  IDL00051334048
# 1                116117_tu17@mail.ru     Татьяна  IDL00051367351
# 2                116117_tu17@mail.ru     Татьяна  IDL00007611755
# 3                116117_tu17@mail.ru     Татьяна  IDL00014478250
# 4                116117_tu17@mail.ru     Татьяна  IDL00001209351
# ...                              ...         ...             ...
# 267686  118117_vu22@kamelia-dress.ru   Александр  IDL00031153351
# 267687  118117_vu22@kamelia-dress.ru   Александр  IDL00031222856
# 267688  118117_vu22@kamelia-dress.ru   Александр  IDL00033741553
# 267689  118117_vu22@kamelia-dress.ru   Александр   ID10005324250
# 267690          98109_bm24@gmail.com  Константин  IDL00028471149
#
#            ГородМагазина МагазинЗаказа НоваяМаржа
# 0       ИнтернетДоставка           NaN        26,9
# 1       ИнтернетДоставка           NaN        8,04
# 2       ИнтернетДоставка           NaN        5,79
# 3       ИнтернетДоставка           NaN       63,79
# 4       ИнтернетДоставка           NaN       95,18
# ...                  ...           ...         ...
# 267686  ИнтернетДоставка           NaN          39
# 267687  ИнтернетДоставка           NaN      202,73
# 267688  ИнтернетДоставка           NaN      -18,25
# 267689  ИнтернетДоставка           NaN         179
# 267690  ИнтернетДоставка           NaN           0
#
# [267691 rows x 39 columns]

# %% [markdown]
# Было: 267691 rows
#
# Стало: 267691 rows
#
# Цифра не изменилась, значит, ошибок по этому пункту в таблице нет

# %%
df
# Out:
#                     Дата      ДатаДоставки НомерЗаказаНаСайте НовыйСтатус  \
# 0       01.07.2017 00:00  06.07.2017 00:00         5031788_TR   Доставлен
# 1       01.07.2017 00:00  06.07.2017 00:00         5031788_TR   Доставлен
# 2       01.07.2017 00:00  06.07.2017 00:00         5031788_TR   Доставлен
# 3       01.07.2017 00:00  06.07.2017 00:00         5031788_TR   Доставлен
# 4       01.07.2017 00:00  06.07.2017 00:00         5031788_TR   Доставлен
# ...                  ...               ...                ...         ...
# 267686  31.08.2017 23:42  04.09.2017 00:00         5412856_TR   Доставлен
# 267687  31.08.2017 23:42  04.09.2017 00:00         5412856_TR   Доставлен
# 267688  31.08.2017 23:42  04.09.2017 00:00         5412856_TR   Доставлен
# 267689  31.08.2017 23:42  04.09.2017 00:00         5412856_TR   Доставлен
# 267690  31.08.2017 23:42  07.09.2017 00:00         5413024_TR   Доставлен
#
#        СуммаЗаказаНаСайте СуммаДокумента МетодДоставки  ФормаОплаты  \
# 0                   1 634          1 634      Магазины  Безналичная
# 1                   1 634          1 634      Магазины  Безналичная
# 2                   1 634          1 634      Магазины  Безналичная
# 3                   1 634          1 634      Магазины  Безналичная
# 4                   1 634          1 634      Магазины  Безналичная
# ...                   ...            ...           ...          ...
# 267686              3 189          3 189      Магазины  Безналичная
# 267687              3 189          3 189      Магазины  Безналичная
# 267688              3 189          3 189      Магазины  Безналичная
# 267689              3 189          3 189      Магазины  Безналичная
# 267690              1 194          1 194      Магазины  Безналичная
#
#                                   Регион             Группа2  ... НомерСтроки  \
# 0                                 Москва  ТЕКСТИЛЬ, ТРИКОТАЖ  ...           3
# 1                                 Москва  ТЕКСТИЛЬ, ТРИКОТАЖ  ...           4
# 2                                 Москва  ТЕКСТИЛЬ, ТРИКОТАЖ  ...           7
# 3                                 Москва  ТЕКСТИЛЬ, ТРИКОТАЖ  ...           1
# 4                                 Москва  ТЕКСТИЛЬ, ТРИКОТАЖ  ...           9
# ...                                  ...                 ...  ...         ...
# 267686  Химки (Московская область район)  ТЕКСТИЛЬ, ТРИКОТАЖ  ...           9
# 267687  Химки (Московская область район)  ТЕКСТИЛЬ, ТРИКОТАЖ  ...           7
# 267688  Химки (Московская область район)  ТЕКСТИЛЬ, ТРИКОТАЖ  ...           3
# 267689  Химки (Московская область район)          ПОДГУЗНИКИ  ...           8
# 267690                         Ярославль          ПОДГУЗНИКИ  ...           1
#
#        КоличествоПроданоКлиенту ДатаЗаказаНаСайте              Телефон_new  \
# 0                             1  30.06.2017 00:00  55574948-52495050484877
# 1                             1  30.06.2017 00:00  55574948-52495050484877
# 2                             1  30.06.2017 00:00  55574948-52495050484877
# 3                             1  30.06.2017 00:00  55574948-52495050484877
# 4                             1  30.06.2017 00:00  55574948-52495050484877
# ...                         ...               ...                      ...
# 267686                        1  31.08.2017 00:00  55575653-55545554554979
# 267687                        1  31.08.2017 00:00  55575653-55545554554979
# 267688                        1  31.08.2017 00:00  55575653-55545554554979
# 267689                        1  31.08.2017 00:00  55575653-55545554554979
# 267690                        1  31.08.2017 00:00  55575048-54534949515576
#
#                 ЭлектроннаяПочта_new      Клиент          ID_SKU  \
# 0                116117_tu17@mail.ru     Татьяна  IDL00051334048
# 1                116117_tu17@mail.ru     Татьяна  IDL00051367351
# 2                116117_tu17@mail.ru     Татьяна  IDL00007611755
# 3                116117_tu17@mail.ru     Татьяна  IDL00014478250
# 4                116117_tu17@mail.ru     Татьяна  IDL00001209351
# ...                              ...         ...             ...
# 267686  118117_vu22@kamelia-dress.ru   Александр  IDL00031153351
# 267687  118117_vu22@kamelia-dress.ru   Александр  IDL00031222856
# 267688  118117_vu22@kamelia-dress.ru   Александр  IDL00033741553
# 267689  118117_vu22@kamelia-dress.ru   Александр   ID10005324250
# 267690          98109_bm24@gmail.com  Константин  IDL00028471149
#
#            ГородМагазина МагазинЗаказа НоваяМаржа
# 0       ИнтернетДоставка           NaN        26,9
# 1       ИнтернетДоставка           NaN        8,04
# 2       ИнтернетДоставка           NaN        5,79
# 3       ИнтернетДоставка           NaN       63,79
# 4       ИнтернетДоставка           NaN       95,18
# ...                  ...           ...         ...
# 267686  ИнтернетДоставка           NaN          39
# 267687  ИнтернетДоставка           NaN      202,73
# 267688  ИнтернетДоставка           NaN      -18,25
# 267689  ИнтернетДоставка           NaN         179
# 267690  ИнтернетДоставка           NaN           0
#
# [267691 rows x 39 columns]

# %%
df.iloc[20:30, 15:30]
# Out:
#    Отменено  ПричинаОтмены  Количество   Цена СуммаСтроки ЦенаЗакупки  \
# 20      Нет            NaN           1  167,3       167,3      152,68
# 21      Нет            NaN           1   97,3        97,3       113,4
# 22      Нет            NaN           1    209         209       152,3
# 23      Нет            NaN           1   97,3        97,3       94,88
# 24      Нет            NaN           1  398,3       398,3      475,68
# 25      Нет            NaN           5    266       1 330      252,56
# 26      Нет            NaN           1    279         279      250,96
# 27      Нет            NaN           1    274         274      250,96
# 28      Нет            NaN           1    349         349      356,04
# 29      Нет            NaN           1    899         899         750
#
#     МесяцДатыЗаказа ГодДатыЗаказа    ПВЗ_код     Статус      Гео   Маржа  \
# 20                7         2 017      23111  Доставлен  Регионы   14,62
# 21                7         2 017      23111  Доставлен  Регионы   -16,1
# 22                7         2 017      23111  Доставлен  Регионы    56,7
# 23                7         2 017      23111  Доставлен  Регионы    2,42
# 24                7         2 017      23111  Доставлен  Регионы  -77,38
# 25                7         2 017  GL0285876  Доставлен       МО    67,2
# 26                7         2 017  GL0285876  Доставлен       МО   28,04
# 27                7         2 017  GL0285876  Доставлен       МО   23,04
# 28                7         2 017      23111  Доставлен  Регионы   -7,04
# 29                7         2 017  GL0285876  Доставлен       МО     149
#
#     СуммаУслуг  СуммаДоставки  НомерСтроки
# 20          99             99            9
# 21          99             99            2
# 22          99             99            7
# 23          99             99            3
# 24          99             99           11
# 25          49             49            1
# 26          49             49            2
# 27          49             49            3
# 28          99             99            1
# 29          49             49            1

# %%
df.to_csv('filtered_dataBuyed2.csv', index=False, sep=';', encoding='utf-8-sig')

# %% [markdown]
# # Создание сводных таблиц

# %%
df = pd.read_csv('filtered_dataBuyed2.csv', sep=';', encoding='utf-8-sig')

# %%
df_2 = df['НомерЗаказаНаСайте'].unique() #проверяем длины по уникальным заказам
len(df_2)
# Out:
# 84368

# %%
new_df = pd.DataFrame(columns=['Месяц', 'Выручка', 'Абсолютная маржа', 'Маржа', 'Кол-во чеков', 'Кол-во товаров', 'Кол-во уникальных клиентов', 'Средний чек', 'Среднее кол-во товаров в чеке', 'Ценность клиента', 'Доля выкупаемости товаров'])
new_df
# Out:
# Empty DataFrame
# Columns: [Месяц, Выручка, Абсолютная маржа, Маржа, Кол-во чеков, Кол-во товаров, Кол-во уникальных клиентов, Средний чек, Среднее кол-во товаров в чеке, Ценность клиента, Доля выкупаемости товаров]
# Index: []

# %%
s = set() #поиск типов для проверки
for el in df['ИспМаржа'].unique():
    s.add(type(el))
s
# Out:
# {numpy.float64}

# %% [markdown]
# ### Мы создаем прототип функции для создания соводной таблицы, для того, чтобы потом менять параметры и получать данные. В функции прописываем методы для поиска того или иного праметра. В даннном нам Dataset числа представлены через разделитель ",", что мешало работать функйии. Для этого мы в таблице использовали функцию в экселе "=ПРЕДСТАВИТЬ(T2;",";".")".

# %%
def generate_table(df, column_name="МесяцДатыЗаказа"): 
    columns_list = [column_name, 'Выручка', 'Абсолютная маржа', 'Маржа', 'Кол-во чеков', 'Кол-во товаров', 'Кол-во уникальных клиентов', 'Средний чек', 'Среднее кол-во товаров в чеке', 'Ценность клиента'] 
    unique_values = df[column_name].unique() 
    total = pd.DataFrame(columns=columns_list)
    for val in unique_values: 
        list_of_values = [val] 
        filtered_df = df[df[column_name] == val] 
        #Подсчет значений 
        profit = int(round(filtered_df['НоваяСуммаСтроки'].sum()))                       #выручка 
        list_of_values.append(profit) 
        
        absmargin = int(round(filtered_df['ИспМаржа'].sum()))                           #абсолютная маржа 
        list_of_values.append(absmargin) 
        
        margin = absmargin/profit                                                #маржа ?
        list_of_values.append(margin) 
        
        df_numb_check = filtered_df['НомерЗаказаНаСайте'].unique()               #кол-во чеков 
        numb_check = df_numb_check.size
        list_of_values.append(numb_check) 
        
        numb_good = filtered_df['МесяцДатыЗаказа'].size                          #кол-во товаров 
        list_of_values.append(numb_good) 
        
        num_of_customers = filtered_df['Телефон_new'].unique().size              #кол-во уникальных клиентов
        list_of_values.append(num_of_customers)

        avarage_bill = int(round(filtered_df.groupby(['НомерЗаказаНаСайте']).mean()['НовСуммаЗаказаНаСайте'].mean())) #средний чек 
        list_of_values.append(avarage_bill)
        
        avarage_numb_good = int(round(filtered_df.groupby(['НомерЗаказаНаСайте']).count()['НовСуммаЗаказаНаСайте'].mean())) #Среднее кол-во товаров в  чеке
        list_of_values.append(avarage_numb_good)
        
        value_of_customer = int(round(absmargin /num_of_customers))                      #ценность клиента
        list_of_values.append(value_of_customer)
        
        tmp_df = pd.DataFrame([list_of_values], columns=columns_list) 
        total = total.append(tmp_df, ignore_index=True)
    return total

# %%
pivot_table = generate_table(df, column_name="МесяцДатыЗаказа")

# %%
pivot_table
# Out:
#   МесяцДатыЗаказа    Выручка Абсолютная маржа     Маржа Кол-во чеков  \
# 0               7  124238397         24383998  0.196268        39826
# 1               8  132317119         22452746  0.169689        44542
#
#   Кол-во товаров Кол-во уникальных клиентов Средний чек  \
# 0         123444                      34242        3261
# 1         144247                      38320        3123
#
#   Среднее кол-во товаров в чеке Ценность клиента
# 0                             3              712
# 1                             3              586

# %%
pivot_table.to_csv('pivot_tableМесяцВыкупленные.csv', index=False, sep=';', encoding='utf-8-sig')

# %%
new_df1 = pd.DataFrame(columns=['Месяц', 'Выручка', 'Абсолютная маржа', 'Маржа', 'Кол-во чеков', 'Кол-во товаров', 'Кол-во уникальных клиентов', 'Средний чек', 'Среднее кол-во товаров в чеке', 'Ценность клиента', 'Доля выкупаемости товаров'])
new_df1
# Out:
# Empty DataFrame
# Columns: [Месяц, Выручка, Абсолютная маржа, Маржа, Кол-во чеков, Кол-во товаров, Кол-во уникальных клиентов, Средний чек, Среднее кол-во товаров в чеке, Ценность клиента, Доля выкупаемости товаров]
# Index: []

# %%
pivot_table = generate_table(df, column_name="Группа2")

# %%
pivot_table
# Out:
#                       Группа2   Выручка Абсолютная маржа     Маржа  \
# 0          ТЕКСТИЛЬ, ТРИКОТАЖ  32624056          7953404  0.243790
# 1           КОСМЕТИКА/ГИГИЕНА   6651888          1007462  0.151455
# 2      КРУПНОГАБАРИТНЫЙ ТОВАР  94964546         25290705  0.266317
# 3             ДЕТСКОЕ ПИТАНИЕ  17409701           777033  0.044632
# 4                  ПОДГУЗНИКИ  40632850           798755  0.019658
# 5                       ОБУВЬ   9419002          1799412  0.191041
# 6        ТОВАРЫ ДЛЯ КОРМЛЕНИЯ   9377756          1395344  0.148793
# 7                     ИГРУШКИ  37469931          6000163  0.160133
# 8    КАНЦТОВАРЫ, КНИГИ, ДИСКИ   5058525          1500506  0.296629
# 9         ТОВАРЫ ДЛЯ ЖИВОТНЫХ   2547444           196705  0.077217
# 10             ЖЕНСКИЕ ШТУЧКИ     85727            34529  0.402779
# 11       СОПУТСТВУЮЩИЕ ТОВАРЫ    111034            36116  0.325270
# 12  ТЕХНИКА И ТОВАРЫ ДЛЯ ДОМА    203056            46609  0.229538
#
#    Кол-во чеков Кол-во товаров Кол-во уникальных клиентов Средний чек  \
# 0         18674          56369                      15544        2869
# 1          9772          26642                       8448        2956
# 2         13070          15296                      12167        8041
# 3          9582          39711                       7397        3207
# 4         20620          29269                      16149        2959
# 5          6619          10171                       5902        2325
# 6          8564          16029                       7760        3249
# 7         24655          52799                      22087        2351
# 8          4535          15148                       4246        2544
# 9          1507           4313                       1257        2765
# 10          342           1135                        327        2636
# 11          321            432                        315        2640
# 12          237            377                        225        2674
#
#    Среднее кол-во товаров в чеке Ценность клиента
# 0                              3              512
# 1                              3              119
# 2                              1             2079
# 3                              4              105
# 4                              1               49
# 5                              2              305
# 6                              2              180
# 7                              2              272
# 8                              3              353
# 9                              3              156
# 10                             3              106
# 11                             1              115
# 12                             2              207

# %%
pivot_table.to_csv('pivot_tableГруппа2Выкупленные.csv', index=False, sep=';', encoding='utf-8-sig')

# %%
pivot_table = generate_table(df, column_name="Группа3")
pivot_table
# Out:
#                            Группа3   Выручка Абсолютная маржа     Маржа  \
# 0         ДЕТСКИЕ КОЛГОТКИ И НОСКИ    533437           165832  0.310875
# 1                 СРЕДСТВА ГИГИЕНЫ   1123442           145731  0.129718
# 2            ИЗДЕЛИЯ ИЗ ПЛАСТМАССЫ    716173           266887  0.372657
# 3                    ДЕТСКОЕ БЕЛЬЁ   1254685           327798  0.261259
# 4           ВЕРХНЯЯ ДЕТСКАЯ ОДЕЖДА  13173018          2976061  0.225921
# ..                             ...       ...              ...       ...
# 90        СВЕТООТРАЖАЮЩИЕ ЭЛЕМЕНТЫ       709              213  0.300423
# 91  ТЕХНИКА ДЛЯ КРАСОТЫ И ЗДОРОВЬЯ      7523             4693  0.623820
# 92   ТОВАРЫ ДЛЯ ЧЕРЕПАХ И РЕПТИЛИЙ      7641              352  0.046067
# 93            ЗАПЧАСТИ ДЛЯ ИГРУШЕК         1                0  0.000000
# 94              ТОВАРЫ ДЛЯ ХОРЬКОВ        69                9  0.130435
#
#    Кол-во чеков Кол-во товаров Кол-во уникальных клиентов Средний чек  \
# 0          1871           5087                       1756        2875
# 1          3647           6068                       3265        3562
# 2          1102           1327                       1080        3888
# 3          2211           3864                       2073        2839
# 4          4433           5272                       4103        3977
# ..          ...            ...                        ...         ...
# 90            1              1                          1        2018
# 91           13             13                         13        3720
# 92            2              2                          2        6166
# 93            1              1                          1           1
# 94            1              1                          1         606
#
#    Среднее кол-во товаров в чеке Ценность клиента
# 0                              3               94
# 1                              2               45
# 2                              1              247
# 3                              2              158
# 4                              1              725
# ..                           ...              ...
# 90                             1              213
# 91                             1              361
# 92                             1              176
# 93                             1                0
# 94                             1                9
#
# [95 rows x 10 columns]

# %%
pivot_table.to_csv('pivot_tableГруппа3Выкупленные.csv', index=False, sep=';', encoding='utf-8-sig')

# %%
pivot_table = generate_table(df, column_name="Регион")
pivot_table
# Out:
#                                  Регион   Выручка Абсолютная маржа     Маржа  \
# 0                                Москва  57302038          8743715  0.152590
# 1                                Самара   4815517           784363  0.162882
# 2                                  Сочи   3069709           639712  0.208395
# 3    Коломна (Московская область район)   1558614           334276  0.214470
# 4                          Новомосковск   1309095           271036  0.207041
# ..                                  ...       ...              ...       ...
# 206          Заря (Балашихинский район)      2871              644  0.224312
# 207           Обухово (Ногинский район)      4468              699  0.156446
# 208             Есино (Ногинский район)       646               55  0.085139
# 209    Заветы Ильича (Пушкинский район)       676              138  0.204142
# 210                            Щербинка      2448              221  0.090278
#
#     Кол-во чеков Кол-во товаров Кол-во уникальных клиентов Средний чек  \
# 0          24219          79176                      19036        2456
# 1           1572           5104                       1228        3214
# 2            739           2642                        539        4393
# 3            495           1551                        355        3271
# 4            453           1459                        338        3022
# ..           ...            ...                        ...         ...
# 206            1              3                          1        2920
# 207            2              3                          2        2394
# 208            1              3                          1         695
# 209            1              3                          1         725
# 210            1              6                          1        2448
#
#     Среднее кол-во товаров в чеке Ценность клиента
# 0                               3              459
# 1                               3              639
# 2                               4             1187
# 3                               3              942
# 4                               3              802
# ..                            ...              ...
# 206                             3              644
# 207                             2              350
# 208                             3               55
# 209                             3              138
# 210                             6              221
#
# [211 rows x 10 columns]

# %%
pivot_table.to_csv('pivot_tableРегионВыкупленные.csv', index=False, sep=';', encoding='utf-8-sig')

# %%
pivot_table = generate_table(df, column_name="ДеньНедели")
pivot_table
# Out:
#   ДеньНедели   Выручка Абсолютная маржа     Маржа Кол-во чеков Кол-во товаров  \
# 0          6  27939397          5679380  0.203275         8483          25734
# 1          7  32493680          6513214  0.200446         9516          28099
# 2          1  38650955          6646239  0.171955        12899          39841
# 3          2  47354501          7937127  0.167611        16614          54760
# 4          3  42479762          7556458  0.177884        14514          49051
# 5          4  37968032          6906918  0.181914        12634          39786
# 6          5  29669190          5597408  0.188661         9708          30420
#
#   Кол-во уникальных клиентов Средний чек Среднее кол-во товаров в чеке  \
# 0                       8075        3454                             3
# 1                       9081        3556                             3
# 2                      12150        3137                             3
# 3                      15395        2994                             3
# 4                      13612        3075                             3
# 5                      11906        3144                             3
# 6                       9239        3221                             3
#
#   Ценность клиента
# 0              703
# 1              717
# 2              547
# 3              516
# 4              555
# 5              580
# 6              606

# %%
pivot_table.to_csv('pivot_tableДеньНеделиВыкупленные.csv', index=False, sep=';', encoding='utf-8-sig')

# %%
pivot_table = generate_table(df, column_name="ВремяОкругл")
pivot_table
# Out:
#    ВремяОкругл   Выручка Абсолютная маржа     Маржа Кол-во чеков  \
# 0     00:00:00  10716698          1697084  0.158359         3934
# 1     01:00:00    388665            57536  0.148035          140
# 2     02:00:00  11205706          1776796  0.158562         4245
# 3     03:00:00   2790342           462831  0.165869         1063
# 4     04:00:00   1176499           195206  0.165921          416
# 5     05:00:00    706219           123984  0.175560          223
# 6     06:00:00   1103641           200904  0.182037          369
# 7     07:00:00   2662744           407550  0.153056          894
# 8     08:00:00   3371370           584476  0.173365         1223
# 9     09:00:00   5674107           945929  0.166710         2009
# 10    10:00:00   9438015          1834051  0.194326         3004
# 11    11:00:00  11806963          2302906  0.195046         3879
# 12    14:00:00  18429822          3452255  0.187319         5857
# 13    15:00:00  18929313          3541740  0.187103         5721
# 14    16:00:00  16444748          3109354  0.189079         5284
# 15    17:00:00  18489645          3330165  0.180110         6002
# 16    18:00:00  15664630          2950113  0.188330         5029
# 17    19:00:00  18349943          3573876  0.194762         5738
# 18    20:00:00  15913180          3154731  0.198246         4830
# 19    21:00:00  10693377          1950719  0.182423         3481
# 20    22:00:00  15792744          2702715  0.171137         5488
# 21    23:00:00  14411980          2438041  0.169168         5156
# 22    12:00:00  16604815          3019222  0.181828         5481
# 23    13:00:00  15790350          3024559  0.191545         4902
#
#    Кол-во товаров Кол-во уникальных клиентов Средний чек  \
# 0           13423                       3811        2850
# 1             422                        138        3038
# 2           15863                       4015        2771
# 3            4361                       1027        2758
# 4            1863                        408        3100
# 5             880                        222        3288
# 6            1165                        355        3136
# 7            2753                        873        3115
# 8            3498                       1190        2895
# 9            5610                       1962        2954
# 10           8589                       2925        3275
# 11          11477                       3769        3163
# 12          17909                       5645        3296
# 13          17499                       5542        3472
# 14          16633                       5124        3249
# 15          18940                       5821        3265
# 16          16218                       4864        3259
# 17          18157                       5576        3352
# 18          15043                       4689        3462
# 19          11081                       3406        3214
# 20          17757                       5295        3005
# 21          17229                       4965        2946
# 22          16269                       5303        3169
# 23          15052                       4759        3380
#
#    Среднее кол-во товаров в чеке Ценность клиента
# 0                              3              445
# 1                              3              417
# 2                              4              443
# 3                              4              451
# 4                              4              478
# 5                              4              558
# 6                              3              566
# 7                              3              467
# 8                              3              491
# 9                              3              482
# 10                             3              627
# 11                             3              611
# 12                             3              612
# 13                             3              639
# 14                             3              607
# 15                             3              572
# 16                             3              607
# 17                             3              641
# 18                             3              673
# 19                             3              573
# 20                             3              510
# 21                             3              491
# 22                             3              569
# 23                             3              636

# %%
pivot_table.to_csv('pivot_tableВремяВыкупленные.csv', index=False, sep=';', encoding='utf-8-sig')

# %%
pivot_table = generate_table(df, column_name="Группа3")
pivot_table
# Out:
#                            Группа3   Выручка Абсолютная маржа     Маржа  \
# 0         ДЕТСКИЕ КОЛГОТКИ И НОСКИ    533437           165832  0.310875
# 1                 СРЕДСТВА ГИГИЕНЫ   1123442           145731  0.129718
# 2            ИЗДЕЛИЯ ИЗ ПЛАСТМАССЫ    716173           266887  0.372657
# 3                    ДЕТСКОЕ БЕЛЬЁ   1254685           327798  0.261259
# 4           ВЕРХНЯЯ ДЕТСКАЯ ОДЕЖДА  13173018          2976061  0.225921
# ..                             ...       ...              ...       ...
# 90        СВЕТООТРАЖАЮЩИЕ ЭЛЕМЕНТЫ       709              213  0.300423
# 91  ТЕХНИКА ДЛЯ КРАСОТЫ И ЗДОРОВЬЯ      7523             4693  0.623820
# 92   ТОВАРЫ ДЛЯ ЧЕРЕПАХ И РЕПТИЛИЙ      7641              352  0.046067
# 93            ЗАПЧАСТИ ДЛЯ ИГРУШЕК         1                0  0.000000
# 94              ТОВАРЫ ДЛЯ ХОРЬКОВ        69                9  0.130435
#
#    Кол-во чеков Кол-во товаров Кол-во уникальных клиентов Средний чек  \
# 0          1871           5087                       1756        2875
# 1          3647           6068                       3265        3562
# 2          1102           1327                       1080        3888
# 3          2211           3864                       2073        2839
# 4          4433           5272                       4103        3977
# ..          ...            ...                        ...         ...
# 90            1              1                          1        2018
# 91           13             13                         13        3720
# 92            2              2                          2        6166
# 93            1              1                          1           1
# 94            1              1                          1         606
#
#    Среднее кол-во товаров в чеке Ценность клиента
# 0                              3               94
# 1                              2               45
# 2                              1              247
# 3                              2              158
# 4                              1              725
# ..                           ...              ...
# 90                             1              213
# 91                             1              361
# 92                             1              176
# 93                             1                0
# 94                             1                9
#
# [95 rows x 10 columns]

# %%
pivot_table.to_csv('Дляменя.csv', index=False, sep=';', encoding='utf-8-sig')
